# %% [markdown]
# <a href="https://colab.research.google.com/github/DivviValliBhargavi/FMML-COURSE-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 13:08:58--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  61.1MB/s    in 1.1s
#
# 2024-03-28 13:09:03 (61.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 9491   1612.00132v2  Problems such as predicting a new shading fiel...    cs
# 10721   1302.3590v1  This paper presents a Bayesian approach to lea...    cs
# 24346   1310.3399v2  In this manuscript we present the technique to...    cs
# 6039   1606.04316v3  The machine learning community adopted the use...  stat
# 40360  cs/0606100v4  This paper has been withdrawn by the author du...    cs
# ...             ...                                                ...   ...
# 13502   1210.0118v1  Self-delimiting (SLIM) programs are a central ...    cs
# 5845    1206.6449v1  Bayesian reinforcement learning (BRL) encodes ...    cs
# 36895  1509.04513v1  The Singleton Property (SP) approach has been ...    cs
# 25937  1512.06539v1  Transient imaging or light-in-flight technique...    cs
# 13041   1311.2972v2  We study the problem of learning a distributio...  stat
#
#                                                    title  year  \
# 9491   CDVAE: Co-embedding Deep Variational Auto Enco...  2016
# 10721  Bayesian Learning of Loglinear Models for Neur...  2013
# 24346  An Improved K-means Clustering Based Approach ...  2013
# 6039   Time for a change: a tutorial for comparing mu...  2016
# 40360  The generating function of the polytope of tra...  2006
# ...                                                  ...   ...
# 13502                    Self-Delimiting Neural Networks  2012
# 5845         Monte Carlo Bayesian Reinforcement Learning  2012
# 36895  On Reasoning with RDF Statements about Stateme...  2015
# 25937  Spatial Phase-Sweep: Increasing temporal resol...  2015
# 13041  Learning Mixtures of Discrete Product Distribu...  2013
#
#                                                 keywords
# 9491   [predicting, ambiguous, solutions, representin...
# 10721  [connectivity, structure, configuration, frequ...
# 24346  [manuscript, technique, structure, haemotoxyli...
# 6039   [community, hypothesis, significance, statisti...
# 40360  [withdrawn, generating, transport, semidefinit...
# ...                                                  ...
# 13502  [delimiting, theoretical, particularly, algori...
# 5845   [reinforcement, knowledge, represents, uncerta...
# 36895  [singleton, representing, provenance, singleto...
# 25937  [transient, techniques, propagation, transient...
# 13041  [distribution, underlying, distribution, distr...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 9491     [predicting, ambiguous, solutions, representin...
# 10721    [connectivity, structure, configuration, frequ...
# 24346    [manuscript, technique, structure, haemotoxyli...
# 6039     [community, hypothesis, significance, statisti...
# 40360    [withdrawn, generating, transport, semidefinit...
#                                ...
# 12550    [algorithms, increasingly, important, decision...
# 2596     [knowledge, construction, extracting, informat...
# 32260    [classification, crowdsourcing, motivated, cha...
# 2344     [algorithm, approximate, inference, probabilis...
# 10810    [programming, framework, interpretable, classi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8721 words.
# Out of those 4583 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="600113e3-0576-44f1-a11f-0b65620024a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("600113e3-0576-44f1-a11f-0b65620024a3")) {                    Plotly.newPlot(                        "600113e3-0576-44f1-a11f-0b65620024a3",                        [{"x":["quantitative","difficult","generation","qualitatively","demonstrate","containing","baselines","ambiguity","conditioned","exploiting","constraint","saturation","variational","prediction","procedure","quantitatively","solutions","relighting","representing","conditional","predicting","different","ambiguous","outperform","embedding","represents","adjustment","distribution","interactions","framework","approximate","configuration","recordings","composition","confirmed","structure","synthetic","performance","understood","attentional","interaction","objective","conjecture","associated","posterior","detecting","generalizes","restricted","probabilities","boltzmann","frequencies","connectivity","statistical","structures","algorithm","processing","detection","clustering","considered","biomedical","signalimage","performed","technique","manuscript","hypothesis","frequentist","reasoning","importantly","development","fallacies","scientific","shortcomings","comparing","classifiers","community","significance","publications","alternatives","generating","semidefinite","withdrawn","marginals","transport","modulation","candidate","functions","significant","classification","classifies","complexity","cumulative","asymptotically","approaches","constellations","optimized","locations","discriminant","collected","directions","qualitative","potential","feasibility","rehabilitation","filtering","formulate","incomplete","recommender","evaluations","conducting","imputation","inference","measurements","collaborative","personalized","distributions","approximating","uncertainty","classical","minimizes","efficient","alternative","typically","divergence","successful","underestimation","regression","expectation","basketball","closeness","minimizing","estimates","minimization","propagation","thresholding","perception","improving","distances","observations","noticeable","differences","alleviate","perceptual","difference","generated","similarly","experiments","constraints","stationary","converges","approximation","intractable","sequential","convergent","questions","variation","unsupervised","motivating","estimation","unanswered","explanatory","computing","connections","appropriate","knowledge","algorithms","representation","probabilistic","objectives","motivates","geometrical","representations","hypothesize","generally","implementing","perspectives","computational","formalism","theoretic","uniqueness","optimization","reformulation","resulting","encountered","theoretical","difficulties","soundness","information","arguments","efficiency","increased","utilizing","important","neighborhood","transformation","modalities","specifically","nonlinear","dimensional","euclidean","disparate"],"y":[76,148,151,23,580,61,50,21,21,96,102,8,49,232,120,29,163,2,65,100,73,728,13,96,108,45,14,198,71,542,117,22,13,31,13,352,112,875,28,9,83,173,13,112,36,74,35,60,54,24,15,18,156,137,825,276,359,152,117,23,1,130,266,8,57,0,134,23,121,1,39,10,62,114,83,20,5,27,108,11,5,5,10,2,58,233,246,500,7,221,15,14,431,2,53,45,17,68,42,50,147,22,5,63,70,31,13,43,8,7,221,60,32,14,99,18,85,102,13,406,75,122,22,72,0,96,32,1,1,46,79,63,67,15,42,121,35,78,5,58,18,23,58,165,21,592,151,22,31,101,20,89,6,75,57,135,8,208,1,4,129,56,80,358,592,352,158,27,9,14,211,4,56,26,13,309,18,45,7,346,3,162,11,162,27,5,652,22,160,43,49,325,23,57,27,172,66,179,24,5],"type":"bar"},{"x":["quantitative","difficult","generation","qualitatively","demonstrate","containing" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4583,), (4583, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>SemanticPaint</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Framework</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.574468085106383);'>Interactive</span> <span style='background-color:rgba(0, 255, 0, 0.7408906882591093);'>Segmentation</span> <span style=''>of</span> <span style=''>3D</span> <span style=''>Scenes</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style=''>open</span> <span style=''>source</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.306930693069307);'>implementation</span> <span style=''>of</span> <span style=''>SemanticPaint</span> <span style=''>a</span> <span style=''>system</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geometric</span> <span style='background-color:rgba(0, 255, 0, 0.3129770992366412);'>reconstruction</span> <span style=''>object</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.7408906882591093);'>segmentation</span> <span style=''>and</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>3D</span> <span style=''>scenes</span> <span style=''>Using</span> <span style=''>our</span> <span style=''>system</span> <span style=''>a</span> <span style=''>user</span> <span style=''>can</span> <span style=''>walk</span> <span style=''>into</span> <span style=''>a</span> <span style=''>room</span> <span style=''>wearing</span> <span style=''>a</span> <span style=''>depth</span> <span style=''>camera</span> <span style=''>and</span> <span style=''>a</span> <span style=''>virtual</span> <span style=''>reality</span> <span style=''>headset</span> <span style=''>and</span> <span style=''>both</span> <span style=''>densely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reconstruct</span> <span style=''>the</span> <span style=''>3D</span> <span style=''>scene</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>interactively</span> <span style=''>segment</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4923076923076923);'>environment</span> <span style=''>into</span> <span style=''>object</span> <span style=''>classes</span> <span style=''>such</span> <span style=''>as</span> <span style=''>chair</span> <span style=''>floor</span> <span style=''>and</span> <span style=''>table</span> <span style=''>The</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>interacts</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>physically</span> <span style=''>with</span> <span style=''>the</span> <span style=''>real</span> <span style=''>world</span> <span style=''>scene</span> <span style=''>touching</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>using</span> <span style=''>voice</span> <span style=''>commands</span> <span style=''>to</span> <span style=''>assign</span> <span style=''>them</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style=''>labels</span> <span style=''>These</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>labels</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leveraged</span> <span style=''>by</span> <span style=''>an</span> <span style=''>online</span> <span style=''>random</span> <span style=''>forest</span> <span style=''>based</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>labels</span> <span style=''>for</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Demixing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Superposition</span> <span style=''>Signals</span> <span style=''>from</span> <span style=''>Periodic</span> <span style=''>and</span> <span style=''>Aperiodic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Observations</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>demixing</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>two</span> <span style=''>(or</span> <span style=''>more)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>vectors</span> <span style=''>from</span> <span style=''>a</span> <span style=''>limited</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>where</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinearity</span> <span style=''>is</span> <span style=''>due</span> <span style=''>to</span> <span style=''>either</span> <span style=''>a</span> <span style=''>periodic</span> <span style=''>or</span> <span style=''>an</span> <span style=''>aperiodic</span> <span style=''>function</span> <span style=''>We</span> <span style=''>study</span> <span style=''>certain</span> <span style=''>families</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>superposition</span> <span style=''>models</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>which</span> <span style=''>provably</span> <span style=''>recovers</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>given</span> <span style=''>(nearly)</span> <span style=''>m</span> <span style=''>mathcalO(s)</span> <span style=''>samples</span> <span style=''>where</span> <span style=''>s</span> <span style=''>denotes</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>level</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>This</span> <span style=''>strictly</span> <span style=''>improves</span> <span style=''>upon</span> <span style=''>previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>demixing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotically</span> <span style=''>matches</span> <span style=''>the</span> <span style=''>best</span> <span style=''>possible</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Agnostically</span> <span style=''>Learning</span> <span style=''>Juntas</span> <span style=''>from</span> <span style=''>Random</span> <span style=''>Walks</span> <br/><br/><span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>g</span> <span style=''>11n</span> <span style=''>11</span> <span style=''>that</span> <span style=''>only</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>kn</span> <span style='background-color:rgba(255, 0, 0, 0.413265306122449);'>variables</span> <span style=''>(so</span> <span style=''>called</span> <span style=''>k</span> <span style=''>juntas)</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>agnostically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learnable</span> <span style=''>from</span> <span style=''>a</span> <span style=''>random</span> <span style=''>walk</span> <span style=''>in</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>in</span> <span style=''>n</span> <span style=''>2k2</span> <span style=''>epsilon</span> <span style=''>k</span> <span style=''>and</span> <span style=''>log(1delta)</span> <span style=''>In</span> <span style=''>other</span> <span style=''>words</span> <span style=''>there</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>the</span> <span style=''>claimed</span> <span style=''>running</span> <span style=''>time</span> <span style=''>that</span> <span style=''>given</span> <span style=''>epsilon</span> <span style=''>delta</span> <span style=''>0</span> <span style=''>and</span> <span style=''>access</span> <span style=''>to</span> <span style=''>a</span> <span style=''>random</span> <span style=''>walk</span> <span style=''>on</span> <span style=''>11n</span> <span style=''>labeled</span> <span style=''>by</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>function</span> <span style=''>f</span> <span style=''>11n</span> <span style=''>11</span> <span style=''>finds</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>at</span> <span style=''>least</span> <span style=''>1</span> <span style=''>delta</span> <span style=''>a</span> <span style=''>k</span> <span style=''>junta</span> <span style=''>that</span> <span style=''>is</span> <span style=''>(opt(f)epsilon)</span> <span style=''>close</span> <span style=''>to</span> <span style=''>f</span> <span style=''>where</span> <span style=''>opt(f)</span> <span style=''>denotes</span> <span style=''>the</span> <span style=''>distance</span> <span style=''>of</span> <span style=''>a</span> <span style=''>closest</span> <span style=''>k</span> <span style=''>junta</span> <span style=''>to</span> <span style=''>f</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularization</span> <span style=''>in</span> <span style=''>Deep</span> <span style=''>Learning</span> <br/><br/><span style=''>Why</span> <span style=''>do</span> <span style=''>large</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>so</span> <span style=''>well</span> <span style=''>on</span> <span style=''>complex</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>or</span> <span style=''>speech</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>What</span> <span style=''>exactly</span> <span style=''>is</span> <span style=''>the</span> <span style=''>role</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>for</span> <span style=''>them</span> <span style=''>These</span> <span style=''>are</span> <span style=''>arguably</span> <span style=''>among</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>open</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>today</span> <span style=''>In</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>and</span> <span style=''>thought</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>provoking</span> <span style=''>paper</span> <span style=''>C</span> <span style=''>Zhang</span> <span style=''>et</span> <span style=''>al</span> <span style=''>several</span> <span style=''>authors</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>that</span> <span style=''>hint</span> <span style=''>at</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>concepts</span> <span style=''>to</span> <span style=''>account</span> <span style=''>for</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>phenomenon</span> <span style=''>The</span> <span style=''>paper</span> <span style=''>stirred</span> <span style=''>quit</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>excitement</span> <span style=''>among</span> <span style=''>the</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style=''>but</span> <span style=''>at</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>it</span> <span style=''>created</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confusion</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discussions</span> <span style=''>on</span> <span style=''>OpenReviewnet</span> <span style=''>testifies</span> <span style=''>The</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>pedagogical</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>make</span> <span style=''>this</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.047840057122456266)
# 	representation (0.12566940378436273)
# 	knowledge (0.12781149589432345)
# 	experimental (0.14137807925740806)
# 	segmentation (0.0767583006069261)
# 	architecture (0.09603712959657265)
# 	different (0.2599071760085684)
# 	detection (0.12816851124598358)
# 	convolutional (0.13102463405926454)
# 	recognition (0.13280971081756515)
#
# Some Statistics words are:
# 	stochastic (0.14007003501750875)
# 	estimation (0.16508254127063532)
# 	theoretical (0.1500750375187594)
# 	variables (0.13856928464232116)
# 	algorithm (0.39469734867433715)
# 	statistical (0.16258129064532267)
# 	distribution (0.18409204602301152)
# 	dimensional (0.17808904452226113)
# 	inference (0.2001000500250125)
# 	regression (0.18459229614807404)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6ae3ed84-6d18-41fa-9ac7-7a72c6c7702f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ae3ed84-6d18-41fa-9ac7-7a72c6c7702f")) {                    Plotly.newPlot(                        "6ae3ed84-6d18-41fa-9ac7-7a72c6c7702f",                        [{"x":["quantitative","difficult","generation","qualitatively","demonstrate","containing","baselines","ambiguity","conditioned","exploiting","constraint","saturation","variational","prediction","procedure","quantitatively","solutions","relighting","representing","conditional","predicting","different","ambiguous","outperform","embedding","represents","adjustment","distribution","interactions","framework","approximate","configuration","recordings","composition","confirmed","structure","synthetic","performance","understood","attentional","interaction","objective","conjecture","associated","posterior","detecting","generalizes","restricted","probabilities","boltzmann","frequencies","connectivity","statistical","structures","algorithm","processing","detection","clustering","considered","biomedical","signalimage","performed","technique","manuscript","hypothesis","frequentist","reasoning","importantly","development","fallacies","scientific","shortcomings","comparing","classifiers","community","significance","publications","alternatives","generating","semidefinite","withdrawn","marginals","transport","modulation","candidate","functions","significant","classification","classifies","complexity","cumulative","asymptotically","approaches","constellations","optimized","locations","discriminant","collected","directions","qualitative","potential","feasibility","rehabilitation","filtering","formulate","incomplete","recommender","evaluations","conducting","imputation","inference","measurements","collaborative","personalized","distributions","approximating","uncertainty","classical","minimizes","efficient","alternative","typically","divergence","successful","underestimation","regression","expectation","basketball","closeness","minimizing","estimates","minimization","propagation","thresholding","perception","improving","distances","observations","noticeable","differences","alleviate","perceptual","difference","generated","similarly","experiments","constraints","stationary","converges","approximation","intractable","sequential","convergent","questions","variation","unsupervised","motivating","estimation","unanswered","explanatory","computing","connections","appropriate","knowledge","algorithms","representation","probabilistic","objectives","motivates","geometrical","representations","hypothesize","generally","implementing","perspectives","computational","formalism","theoretic","uniqueness","optimization","reformulation","resulting","encountered","theoretical","difficulties","soundness","information","arguments","efficiency","increased","utilizing","important","neighborhood","transformation","modalities","specifically","nonlinear","dimensional","euclidean","disparate","correspondence","calculated","selection","coefficient","correlation","inexpensive","developed","improvement","biocaster","available","enhancing","influenza","enhancements","according","emoticons","positioning","localization","extensive","parameters","strengths","coordinate","backpropagation","fingerprinting","correspondingly","neighbors","artificial","construction","simulations","summarizing","application","particular","continuous","numerical","recurrent","component","indispensable","traditional","forecasting","competitive","dependency","predictive","multivariate","applications","evaluation","empirical","requiring","characterize","compressive","adaptivity","adaptively","compressed","magnitude","tradeoffs","recovering","requirement" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	frequentist
# 	underestimation
# 	blackwellisation
# 	penalizations
# 	terminate
# 	subroutines
# 	graphically
# 	proportionality
# 	adaboosts
# 	schizophrenia
# 	psychiatric
# 	intentionally
# 	acceptancerejection
# 	affinities
# 	seasonality
# 	temperatures
# 	purchasing
# 	varepsilon
# 	archetypal
# 	stragglers
# Some words which never appear in Statistics papers:
# 	relighting
# 	attentional
# 	withdrawn
# 	biocaster
# 	emoticons
# 	associating
# 	linguistically
# 	exercised
# 	definitional
# 	summarizer
# 	subsumption
# 	broadcast
# 	subtitles
# 	landmarking
# 	establishment
# 	delineate
# 	subdivide
# 	delineation
# 	enclosing
# 	backtracking

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068143466388488e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
